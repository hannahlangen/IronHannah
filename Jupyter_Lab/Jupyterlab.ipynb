# %% [markdown]
# # My skiing trip to Switzerland

# %% [markdown]
# ### I will introduce myself and my favourite way to spend my holidays, which is skiing.

# %%
input("Enter your name: ")
# Out:
# Enter your name: Hannah
# 'Hannah'

# %% [markdown]
# ![Ski_Laax2022.jpeg](attachment:Ski_Laax2022.jpeg)

# %%
def preferences():
    
    preference1=input("What´s your favourite thing about skiing? ")
    print("My favourite thing about skiing is" , preference1)
    
    preference2=input("What else do you enjoy about it? ")
    print("I also enjoy" , preference2)

# %%
preferences()
# Out:
# What´s your favourite thing about skiing? spending time with my family
# My favourite thing about skiing is spending time with my family
# What else do you enjoy about it? being outside
# I also enjoy being outside

# %% [markdown]
# ![ChamperySwitzerland-2020-CW0FHE.jpg.webp](attachment:ChamperySwitzerland-2020-CW0FHE.jpg.webp)

# %% [markdown]
# ### <span style="color:green">Youtube: Laax skiing (GoPro) 2020

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('watch?v=bxUaWOBNiUc', width=800, height=300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="https://www.youtube.com/embed/watch?v=bxUaWOBNiUc"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Top 3 things I like to do
# -  *have coffee at the top of the mountain*
# -  **actually being on the slopes**
# -  <span style="color:blue">admiring the view from the lifts
